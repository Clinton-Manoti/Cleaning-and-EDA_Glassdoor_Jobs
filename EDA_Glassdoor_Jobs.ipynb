# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Read the DataFrame and display all the rows

# %%
df_modified = pd.read_csv(r"C:\Users\Clinton Ombiro\Desktop\Python Datasets\salary_data_cleaned.csv")
pd.set_option('display.max_rows', None)

# %% [markdown]
# #### Display the first five rows

# %%
df_modified.head()
# Out:
#                    Job Title Salary Estimate  \
# 0             Data Scientist      $53K-$91K
# 1  Healthcare Data Scientist     $63K-$112K
# 2             Data Scientist      $80K-$90K
# 3             Data Scientist      $56K-$97K
# 4             Data Scientist     $86K-$143K
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name     Location Headquarters  \
# 0                      Tecolote Research  Albuquerque       Goleta
# 1  University of Maryland Medical System    Linthicum    Baltimore
# 2                                KnowBe4   Clearwater   Clearwater
# ...

# %% [markdown]
# #### Check the columns of the DataFrame

# %%
df_modified.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer provided', 'min_salary', 'max_salary', 'avg_salary',
#        'Same_Location_Hqtrs', 'company_age', 'Python', 'R', 'Excel', 'aws',
#        'Spark'],
#       dtype='object')

# %% [markdown]
# #### Create functions 'title_simplier' and 'seniority' to be applied later

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'machine learning'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower() or 'junior' in title.lower():
        return 'junior'
    else:
        return 'na'

# %% [markdown]
# #### Create a column 'job_simp' to show the kind of roles in the Job Title

# %%
df_modified["job_simp"] = df_modified["Job Title"].apply(title_simplifier)
df_modified.job_simp.value_counts()
# Out:
# data scientist      279
# na                  184
# data engineer       119
# analyst             102
# manager              22
# machine learning     22
# director             14
# Name: job_simp, dtype: int64

# %%
df_modified.head()
# Out:
#                    Job Title Salary Estimate  \
# 0             Data Scientist      $53K-$91K
# 1  Healthcare Data Scientist     $63K-$112K
# 2             Data Scientist      $80K-$90K
# 3             Data Scientist      $56K-$97K
# 4             Data Scientist     $86K-$143K
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name     Location Headquarters  \
# 0                      Tecolote Research  Albuquerque       Goleta
# 1  University of Maryland Medical System    Linthicum    Baltimore
# 2                                KnowBe4   Clearwater   Clearwater
# ...

# %% [markdown]
# #### Create a column 'seniority' to check the number of senior or junior roles

# %%
df_modified["seniority"] = df_modified["Job Title"].apply(seniority)
df_modified.seniority.value_counts()
# Out:
# na        519
# senior    220
# junior      3
# Name: seniority, dtype: int64

# %%
df_modified.head()
# Out:
#                    Job Title Salary Estimate  \
# 0             Data Scientist      $53K-$91K
# 1  Healthcare Data Scientist     $63K-$112K
# 2             Data Scientist      $80K-$90K
# 3             Data Scientist      $56K-$97K
# 4             Data Scientist     $86K-$143K
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name     Location Headquarters  \
# 0                      Tecolote Research  Albuquerque       Goleta
# 1  University of Maryland Medical System    Linthicum    Baltimore
# 2                                KnowBe4   Clearwater   Clearwater
# ...

# %% [markdown]
# #### Get the location with the highest number of job postings

# %%
df_modified["Location"].value_counts()
# Out:
# New York               55
# San Francisco          49
# Cambridge              48
# Chicago                32
# Boston                 23
# San Jose               13
# Pittsburgh             12
# Rockville              11
# Washington             11
# Springfield            10
# Herndon                10
# Richland               10
# Winston-Salem          10
# San Diego               9
# Indianapolis            9
# South San Francisco     8
# Austin                  8
# Mountain View           8
# Rochester               7
# Palo Alto               7
# Salt Lake City          6
# Marlborough             6
# Huntsville              6
# Charlotte               6
# Chantilly               6
# Dallas                  6
# Gaithersburg            6
# Phoenix                 6
# Milwaukee               5
# Seattle                 5
# Cincinnati              5
# Denver                  5
# Worcester               5
# Nashville               5
# Philadelphia            5
# ...

# %% [markdown]
# #### Get the length of the Job Descriptions

# %%
df_modified["descr_len"] = [len(x) for x in df_modified["Job Description"]]
df_modified["descr_len"]
# Out:
# 0       2536
# 1       4783
# 2       3461
# 3       3883
# 4       2728
# 5       3747
# 6       1786
# 7       3804
# 8       1538
# 9       4574
# 10      2757
# 11      3490
# 12      3934
# 13      4897
# 14      3731
# 15      1889
# 16      3639
# 17      4163
# 18      3512
# 19      4397
# 20      2918
# 21      6909
# 22      6408
# 23      2907
# 24      3760
# 25      3698
# 26      4420
# 27      4900
# 28      5015
# 29      3461
# 30      3883
# 31      3342
# 32      5045
# 33      2327
# 34      2161
# 35      1739
# 36      5000
# 37      3703
# 38      3555
# 39      1739
# 40      3053
# 41      1996
# 42      3833
# 43      3550
# 44      9120
# 45      3213
# 46      7286
# 47      3412
# 48      2682
# 49      2739
# 50      2915
# 51      4244
# 52      1629
# 53      4734
# 54      4448
# 55      3543
# 56      4203
# 57      5020
# 58      1786
# 59      3747
# 60      4804
# 61      1382
# 62      2933
# 63      4945
# 64      2493
# 65      1939
# ...

# %% [markdown]
# #### Create a column called 'num_comp' to show the number of competitors each company has

# %%
df_modified["num_comp"] = df_modified["Competitors"].apply(lambda x: 0 if x=='None' else len(x.split(',')))
df_modified.num_comp.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    3
# 4    3
# Name: num_comp, dtype: int64

# %% [markdown]
# #### Use describe method to get some statistical summary of the DataFrame

# %%
df_modified.describe()
# Out:
#            Rating      Founded      hourly  employer provided     min_salary  \
# count  742.000000   742.000000  742.000000         742.000000     742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74068.733154
# std      0.801210   497.183763    0.177034           0.149721   31869.282073
# min     -1.000000    -1.000000    0.000000           0.000000   10000.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52000.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69500.000000
# 75%      4.000000  2007.000000    0.000000           0.000000   91000.000000
# max      5.000000  2019.000000    1.000000           1.000000  202000.000000
#
#           max_salary     avg_salary  Same_Location_Hqtrs  company_age  \
# count     742.000000     742.000000           742.000000   742.000000
# mean   127183.288410  100626.010782             0.559299    48.456873
# ...

# %% [markdown]
# #### Check the columns names

# %%
df_modified.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer provided', 'min_salary', 'max_salary', 'avg_salary',
#        'Same_Location_Hqtrs', 'company_age', 'Python', 'R', 'Excel', 'aws',
#        'Spark', 'job_simp', 'seniority', 'descr_len', 'num_comp'],
#       dtype='object')

# %% [markdown]
# #### Plot a histogram for the Rating column

# %%
df_modified.Rating.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Plot a histogram for the avg_salary column

# %%
df_modified.avg_salary.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Plot a histogram for the company age column

# %%
df_modified.company_age.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Display the company age column

# %%
df_modified.company_age
# Out:
# 0       49
# 1       38
# 2       12
# 3       57
# 4       24
# 5       22
# 6       14
# 7       17
# 8        8
# 9       13
# 10      11
# 11      54
# 12      60
# 13      10
# 14     241
# 15      27
# 16      11
# 17      11
# 18      12
# 19     107
# 20      10
# 21       9
# 22      27
# 23      87
# 24      10
# 25     173
# 26      70
# 27     170
# 28     173
# 29      12
# 30      57
# 31      25
# 32      26
# 33      26
# 34      48
# 35      14
# 36      53
# 37      12
# 38     152
# 39      37
# 40      14
# 41      -1
# 42      12
# 43       7
# 44      29
# 45      -1
# 46      64
# 47      36
# 48      23
# 49      97
# 50      38
# 51     110
# 52      20
# 53     159
# 54      83
# 55     152
# 56      10
# 57       6
# 58      14
# 59      22
# 60     137
# 61      11
# 62      16
# 63      57
# 64      74
# 65      16
# 66      19
# 67      23
# 68      -1
# 69      83
# 70       7
# 71      95
# 72      44
# 73      12
# 74     162
# 75      83
# ...

# %% [markdown]
# #### PLot a histogram for the length of Job Description column

# %%
df_modified.descr_len.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Plot a box plot for the company age and Rating columns

# %%
df_modified.boxplot(column=['company_age', 'Rating'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Plot a box plot for the avg_salary column

# %%
df_modified.boxplot(column = 'avg_salary')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Find the correlation of the specified columns

# %%
df_modified[['company_age', 'avg_salary', 'Rating', 'descr_len']].corr()
# Out:
#              company_age  avg_salary    Rating  descr_len
# company_age     1.000000    0.019492  0.024665   0.164461
# avg_salary      0.019492    1.000000  0.013492   0.078808
# Rating          0.024665    0.013492  1.000000  -0.012281
# descr_len       0.164461    0.078808 -0.012281   1.000000

# %% [markdown]
# #### Plot a heatmap to show the correlation of the specified columns

# %%
fig,ax = plt.subplots()
ax.set_xticklabels(['None','company_age', 'avg_salary', 'Rating', 'descr_len', 'num_comp'],fontsize=7)
ax.set_yticklabels(['None','company_age', 'avg_salary', 'Rating', 'descr_len', 'num_comp'],fontsize=10)
#heatmap = ax.pcolor(df_modified, edgecolors='k')
plt.imshow(df_modified[['company_age', 'avg_salary', 'Rating', 'descr_len', 'num_comp']].corr(), interpolation='nearest')
plt.show()
# Out:
# <ipython-input-23-a5e7f494e87c>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['None','company_age', 'avg_salary', 'Rating', 'descr_len', 'num_comp'],fontsize=7)
# <ipython-input-23-a5e7f494e87c>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['None','company_age', 'avg_salary', 'Rating', 'descr_len', 'num_comp'],fontsize=10)

# %% [markdown]
# #### Display the DataFrame columns

# %%
df_modified.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer provided', 'min_salary', 'max_salary', 'avg_salary',
#        'Same_Location_Hqtrs', 'company_age', 'Python', 'R', 'Excel', 'aws',
#        'Spark', 'job_simp', 'seniority', 'descr_len', 'num_comp'],
#       dtype='object')

# %% [markdown]
# #### Create a pivot table to show the average salary salaries of the different Data Science roles

# %%
pd.pivot_table(df_modified, index='job_simp', values='avg_salary')
# Out:
#                      avg_salary
# job_simp
# analyst            65857.843137
# data engineer     105403.361345
# data scientist    117564.516129
# director          168607.142857
# machine learning  126431.818182
# manager            84022.727273
# na                 84853.260870

# %% [markdown]
# #### Create a pivot table showing the average salary of different roles according to seniority

# %%
pd.pivot_table(df_modified, index=['job_simp', 'seniority'], values='avg_salary')
# Out:
#                                avg_salary
# job_simp         seniority
# analyst          junior      53250.000000
#                  na          61308.219178
#                  senior      79092.592593
# data engineer    na          96701.219512
#                  senior     124689.189189
# data scientist   junior     106500.000000
#                  na         107043.010753
#                  senior     138956.521739
# director         na         168607.142857
# machine learning na         119133.333333
#                  senior     142071.428571
# manager          na          84022.727273
# na               na          73988.188976
#                  senior     109061.403509

# %% [markdown]
# #### Create a pivot table to show the average salary for different locations from highest paying to lowest

# %%
pd.pivot_table(df_modified, index='Location', values='avg_salary').sort_values('avg_salary', ascending=False)
# Out:
#                         avg_salary
# Location
# Bellevue             184500.000000
# Lake Forest          179500.000000
# Mountain View        177187.500000
# Novato               168000.000000
# Burbank              164000.000000
# Emeryville           153000.000000
# Newark               146000.000000
# Fort Lee             145666.666667
# Jersey City          144750.000000
# Brisbane             143500.000000
# Saint Louis          143500.000000
# San Jose             142461.538462
# Cupertino            142000.000000
# Marlborough          142000.000000
# Foster City          139500.000000
# Natick               139500.000000
# Plano                139000.000000
# San Francisco        137244.897959
# Santa Clara          134000.000000
# Arvada               133500.000000
# Los Angeles          132125.000000
# Palo Alto            131285.714286
# Laurel               130000.000000
# Ann Arbor            130000.000000
# Allentown            127500.000000
# ...

# %% [markdown]
# #### Create a pivot table to show the average salary of different roles in specified locations from the highest paying to lowest

# %%
pd.set_option('display.max_rows', None)
pd.pivot_table(df_modified, index=['Location', 'job_simp'], values='avg_salary').sort_values('Location', ascending=False)
# Out:
#                                          avg_salary
# Location            job_simp
# Worcester           data scientist    146500.000000
#                     analyst            51833.333333
# Woodbridge          data scientist     98500.000000
# Woburn              data scientist    110000.000000
# Winter Park         data engineer      71500.000000
# Winston-Salem       na                 96000.000000
# Westlake            data scientist    110500.000000
# West Reading        na                 20500.000000
# West Palm Beach     analyst            44000.000000
# Watertown           na                 37000.000000
# Washington          data scientist    149000.000000
#                     data engineer      85000.000000
#                     analyst            63500.000000
# Waltham             data scientist     94000.000000
# Vancouver           na                 97500.000000
#                     data scientist    128000.000000
# ...

# %% [markdown]
# #### Create a pivot table to show the number of jobs in each location for various roles

# %%
pd.pivot_table(df_modified, index=['Location', 'job_simp'],values='avg_salary', aggfunc='count').sort_values('Location', ascending=False)
# Out:
#                                       avg_salary
# Location            job_simp
# Worcester           data scientist             2
#                     analyst                    3
# Woodbridge          data scientist             2
# Woburn              data scientist             1
# Winter Park         data engineer              2
# Winston-Salem       na                        10
# Westlake            data scientist             2
# West Reading        na                         2
# West Palm Beach     analyst                    2
# Watertown           na                         1
# Washington          data scientist             5
#                     data engineer              4
#                     analyst                    2
# Waltham             data scientist             1
# Vancouver           na                         1
#                     data scientist             1
# Valencia            na                         1
# Vail                na                         3
# ...

# %% [markdown]
# #### Check the number of analysts required in the DataFrame

# %%
df_modified[df_modified["job_simp"]=='analyst'].count()[0]
# Out:
# 102

# %% [markdown]
# #### Check the number of Data Scientists required in the DataFrame

# %%
df_modified[df_modified["job_simp"]=='data scientist'].count()[0]
# Out:
# 279

# %% [markdown]
# #### Check the number of Machine Learners required in the DataFrame

# %%
df_modified[df_modified["job_simp"]=='machine learning'].count()[0]
# Out:
# 22

# %% [markdown]
# #### Create a pivot table to show how much Data Scientists earn in different locations, from the highest paying to the lowest

# %%
pd.pivot_table(df_modified[df_modified['job_simp']=='data scientist'], index=['Location', 'job_simp'],values='avg_salary').sort_values('avg_salary', ascending=False)
# Out:
#                                        avg_salary
# Location            job_simp
# Bellevue            data scientist  184500.000000
# South San Francisco data scientist  167000.000000
# Burbank             data scientist  164000.000000
# Mountain View       data scientist  156375.000000
# Phila               data scientist  155000.000000
# Emeryville          data scientist  153000.000000
# San Francisco       data scientist  152600.000000
# San Jose            data scientist  149250.000000
# Washington          data scientist  149000.000000
# Worcester           data scientist  146500.000000
# Brisbane            data scientist  143500.000000
# Saint Louis         data scientist  143500.000000
# Gaithersburg        data scientist  142500.000000
# Cupertino           data scientist  142000.000000
# Los Angeles         data scientist  141833.333333
# Salt Lake City      data scientist  140500.000000
# Foster City         data scientist  139500.000000
# ...

# %% [markdown]
# #### Create a pivot table to show much Analysts earn in different locations, from the highest paying to the lowest

# %%
pd.pivot_table(df_modified[df_modified['job_simp']=='analyst'], index=['Location', 'job_simp'], values='avg_salary').sort_values('avg_salary', ascending=False)
# Out:
#                              avg_salary
# Location        job_simp
# Jersey City     analyst   173000.000000
# Dublin          analyst   123500.000000
# Glen Burnie     analyst   107500.000000
# San Francisco   analyst   106357.142857
# San Jose        analyst   106000.000000
# Providence      analyst   100000.000000
# San Mateo       analyst    92500.000000
# Dayton          analyst    79000.000000
# Hamilton        analyst    77500.000000
# Minneapolis     analyst    76000.000000
# Blue Bell       analyst    72500.000000
# Patuxent River  analyst    72500.000000
# Herndon         analyst    72333.333333
# Alexandria      analyst    71000.000000
# Portsmouth      analyst    70500.000000
# Springfield     analyst    67666.666667
# Philadelphia    analyst    67500.000000
# Chicago         analyst    66500.000000
# New York        analyst    65607.142857
# Washington      analyst    63500.000000
# Boise           analyst    63500.000000
# Huntsville      analyst    62200.000000
# ...

# %% [markdown]
# #### Display all the columns in the DataFrame

# %%
df_modified.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer provided', 'min_salary', 'max_salary', 'avg_salary',
#        'Same_Location_Hqtrs', 'company_age', 'Python', 'R', 'Excel', 'aws',
#        'Spark', 'job_simp', 'seniority', 'descr_len', 'num_comp'],
#       dtype='object')

# %% [markdown]
# #### Create a variable named 'df_modified_pivots' with the specified columns

# %%
df_modified_pivots =  df_modified[['Rating', 'Industry', 'Sector', 'Revenue', 'num_comp', 'hourly', 'employer provided', 'Python', 'R', 'Spark', 'Excel', 'aws', 'descr_len', 'avg_salary']]

# %% [markdown]
# #### Display the average salary as per the company ratings from the highest paying to lowest

# %%
for i in df_modified_pivots.columns:
    print (i)
    print (pd.pivot_table(df_modified_pivots, index=i, values= 'avg_salary').sort_values('avg_salary', ascending=False))
# Out:
# Rating
#            avg_salary
# Rating
# -1.0    136181.818182
#  5.0    134700.000000
#  2.5    120000.000000
#  4.5    117714.285714
#  4.1    116368.421053
#  3.9    113071.428571
#  2.6    109083.333333
#  4.4    108606.060606
#  3.2    105500.000000
#  4.0    105340.425532
#  3.5    104897.959184
#  3.7    104131.147541
#  4.7    103983.870968
#  4.3    102468.750000
#  3.3    101858.974359
#  4.2    100442.307692
#  2.2     97750.000000
#  4.6     97250.000000
#  3.8     96811.475410
#  2.1     95900.000000
#  3.4     93011.363636
#  1.9     87500.000000
#  3.1     86580.000000
#  3.0     85588.235294
#  3.6     85467.391304
#  2.8     83928.571429
#  2.7     83250.000000
#  2.3     81500.000000
#  2.9     81138.888889
#  4.8     80277.777778
#  2.4     60214.285714
# Industry
#                                              avg_salary
# Industry
# Other Retail Stores                       163500.000000
# Motion Picture Production & Distribution  146000.000000
# ...

# %% [markdown]
# #### Create a pivot table to show the companies by revenue that require Python as a skill, 1 if yes else 0

# %%
pd.pivot_table(df_modified_pivots, index='Revenue', columns='Python', values='avg_salary', aggfunc='count')
# Out:
# Python                               0      1
# Revenue
# $1 to $2 billion (USD)            16.0   44.0
# $1 to $5 million (USD)             1.0    7.0
# $10 to $25 million (USD)          16.0   16.0
# $10+ billion (USD)                66.0   58.0
# $100 to $500 million (USD)        47.0   44.0
# $2 to $5 billion (USD)            17.0   22.0
# $25 to $50 million (USD)          24.0   16.0
# $5 to $10 billion (USD)            9.0   10.0
# $5 to $10 million (USD)            9.0    9.0
# $50 to $100 million (USD)         21.0   25.0
# $500 million to $1 billion (USD)  29.0   28.0
# -1                                 1.0    NaN
# Less than $1 million (USD)         1.0    3.0
# Unknown / Non-Applicable          93.0  110.0

# %% [markdown]
# #### Create a pivot table to show the companies by revenue that require Excel as a skill, 1 if yes else 0

# %%
pd.pivot_table(df_modified_pivots, index='Revenue', columns='Excel', values='avg_salary', aggfunc='count')
# Out:
# Excel                                0      1
# Revenue
# $1 to $2 billion (USD)            26.0   34.0
# $1 to $5 million (USD)             6.0    2.0
# $10 to $25 million (USD)          19.0   13.0
# $10+ billion (USD)                58.0   66.0
# $100 to $500 million (USD)        40.0   51.0
# $2 to $5 billion (USD)            16.0   23.0
# $25 to $50 million (USD)          13.0   27.0
# $5 to $10 billion (USD)            7.0   12.0
# $5 to $10 million (USD)            7.0   11.0
# $50 to $100 million (USD)         29.0   17.0
# $500 million to $1 billion (USD)  41.0   16.0
# -1                                 NaN    1.0
# Less than $1 million (USD)         3.0    1.0
# Unknown / Non-Applicable          89.0  114.0

# %%
df_modified.to_csv('EDA_Glassdoor_Jobs.csv', index=False)
